# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

t = np.linspace(0, 1, 1000)
m = 0.1
k = 100
w = np.sqrt(k/m)
g = 9.81

v0 = 3.1

x = v0/w*np.sin(w*t) - g/w**2*np.cos(w*t) + g/w**2

v = w*(v0/w*np.cos(w*t) + g/w**2*np.sin(w*t))


plt.plot(t, x)

b = 5 

A = -m/b*(3.1 - m*g/b)

x = A*(np.exp(-b/m*t) - 1) +m*g/b*t


v = -b/m*A*(np.exp(-b/m*t)) +m*g/b

plt.plot(t, x)

a = 30 # m/s/s

x = v0*t - a*t**2/2

ix = np.argmax(x)

x[ix:] = np.max(x)

plt.plot(t, x)
